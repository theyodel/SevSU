# %% [markdown]
# <center>
# <font face="Times New Roman" size="4.5">
# <div style="line-height: 1.5;">
# Министерство науки и высшего образования Российской Федерации <br>
# Федеральное государственное автономное образовательное учреждение высшего образования «Севастопольский государственный университет»<br>
# Факультет Информационных технологий<br>
# Кафедра «Информационные технологии и системы»<br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# "Программирование на языке Python"<br>
# "Интерактивный блокнот №7"
# </font>
# </center>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <div align="right">
# <font face="Times New Roman" size="4.5">
# <div style="line-height: 1.5;">
# Выполнил:<br>
# Студент группы ИИ/б-25-6-о Заварзин А.В.<br>
# </div>
# </font>
# </div>
# <center>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <font face="Times New Roman" size="4.5">
# <div style="line-height: 1.5;">
# Севастополь <br>
# 2026<br>
# </font>
# </center>

# %% [markdown]
# # Особенности работы с изменяемыми типами данных
# Для начала я хотел бы обсудить некоторые тонкости при работе со
# списками, словарями и другими изменяемыми типами данных.
#
# Рассмотрим простой пример вызова функции.

# %%
def my_func(x):
    x = x + 1
    return x

# %% [markdown]
# Эта функция увеличивает свой аргумент на единицу и возвращает то, что
# получилось.

# %%
y = 5
print("Функция возвращает", my_func(y))
print("y =", y)
# Out:
# Функция возвращает 6
# y = 5

# %% [markdown]
# Ничего неожиданного. Функция не изменила переменную `y` и не
# должна была этого делать. Давайте теперь попробуем сделать что-то
# аналогичное со списком.

# %%
def other_func(my_list):
    my_list.append(1)
    return my_list

# %% [markdown]
# Эта функция получает в качестве аргумента список, добавляет к нему в
# конец элемент `1` и возвращает то, что получилось. Попробуем её
# вызвать:

# %%
this_list = [6, 9, 33]
print("this_list до функции:",this_list)
print("функция возвращает:",other_func(this_list))
print("this_list после функции", this_list)
# Out:
# this_list до функции: [6, 9, 33]
# функция возвращает: [6, 9, 33, 1]
# this_list после функции [6, 9, 33, 1]

# %% [markdown]
# Ой. Произошло что-то странное. Функция `other_func`
# модифицировала список, который ей был передан, хотя создан он был
# вне этой функций и внутри функции не был определён как `global` (да
# и вообще, внутри функции работа велась с другой переменной).
#
# Почему это произошло? Чтобы разобрать в этом вопросе, проще всего

# %%
# %load_ext tutormagic

# %%
# %%tutor --lang python3
# def other_func(my_list):
#     my_list.append(1)
#     return my_list
#
# this_list = [6, 9, 33]
# other_func(this_list)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="http://pythontutor.com/iframe-embed.html#code=def%20other_func%28my_list%29%3A%0A%20%20%20%20my_list.append%281%29%0A%20%20%20%20return%20my_list%0A%0Athis_list%20%3D%20%5B6%2C%209%2C%2033%5D%0Aother_func%28this_list%29%0A&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=3&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Две сортировки
# Давайте рассмотрим ещё два примера, которые показывают различие
# между этими двумя сценариями — в них снова будут участвовать
# списки. Выполните две визуализации и найдите, в чём разница. После
# этого читайте дальше.

# %%
# %%tutor --lang python3
# def return_sorted(my_list):
#     my_list = sorted(my_list) # сортируем список с помощью sorted(), создавая новый массив (новый указатель)
#     return my_list # возвращаемся в первый
#
# this_list = [33, 1, 55]
# print("this_list до функции:", this_list)
# print("функция возвращает:", return_sorted(this_list))
# print("this_list после функции:", this_list)
# Out:
#         <iframe
#             width="100%"
#             height="350"
# ...

# %%
# %%tutor --lang python3
# def sort_and_return(my_list):
#     my_list.sort() # сортируем массив с помощью метода .sort(), тем самым мы сортируем массив "на месте" (указатель не меняется)
#     return my_list
#
# this_list = [33, 1, 55]
# print("this_list до функции:", this_list)
# print("функция возвращает:", sort_and_return(this_list))
# print("this_list после функции:", this_list)
# Out:
#         <iframe
#             width="100%"
#             height="350"
# ...

# %% [markdown]
# Итак, в чём разница?
#
# Функции `return_sorted()` и `sort_and_return()` выполняют
# примерно одну и ту же работу: принимают на вход список, сортируют
# его и возвращают. В тот момент, когда происходит вход в функцию (Step
# 5), ситуация в обоих фрагментах идентична: вне функции есть
# переменная `this_list`, внутри функции есть переменная `my_list`,
# они обе указывают на один и тот же список. Ключевое различие происходит на следующем шаге. Функция `return_sorted()`
# использует функцию `sorted()` , создающую новый список. Затем она
# присваивает ( `=` ) результат выполнения `sorted()` переменной
# `my_list` . Это приводит к тому, что переменная с этим именем начинает
# ссылаться на новый объект (Step 7), а старый (на который по-прежнему
# ссылается `this_list` ) остаётся в неприкосновенности. Совсем иначе
# действует `sort_and_return()` — она использует метод `sort()`,
# сортирующий список *in place*, внутри самого себя. При этом новый
# объект не создаётся, операция присваивания не используется и
# переменная `my_list` продолжает ссылаться на тот же список, что и
# раньше. Просто он оказывается отсортированным.
#
# Обратите внимание на схожесть `return_sorted()` и `my_func()` из
# примера выше: в обоих случаях используется оператор присваивания.
# Разница состоит в том, что с числовой переменной никак иначе
# поступить было нельзя, поскольку числа неизменяемы, а в случае со
# списком у разработчика есть выбор: можно создать новый объект и
# присвоить его старой переменной, а можно изменить уже существующий
# объект, не создавая новый.

# %% [markdown]
# ## Создание копии
# Предположим теперь, что мы хотим написать функцию, которая
# принимает на вход список, возвращает такой же список, но с одним
# добавленным элементом, а сам исходный список не меняет. Это можно
# сделать, например, вот так:

# %%
def return_append(L, a):
    new_L = L.copy() # создаём копию списка L в новый указатель, тем самым мы не изменим подаваемый на входе в функцию список
    new_L.append(a)
    return new_L

# %%
outer_list = [7, 8, 9]
print("outer_list до функции", outer_list)
print("функция возвращает", return_append(outer_list, 55))
print("outer_list после функции", outer_list)
# Out:
# outer_list до функции [7, 8, 9]
# функция возвращает [7, 8, 9, 55]
# outer_list после функции [7, 8, 9]

# %% [markdown]
# Здесь главная хитрость в использовании `L.copy()` — напомним, что
# этот метод создаёт копию существующего списка. Дальше мы снова
# выполняем операцию присваивания (то есть теперь `new_L` является именем для копии списка `L`, а не для самого списка `L`) и мы можем
# делать с этим новым списком `new_L` что угодно. Старый список не изменится.

# %% [markdown]
# ### Различные способы создания копий списков
# Помимо `.copy()`, есть и другие способы создать копию списка:

# %%
original = [1, 2, 3]

copy1 = original.copy() # метод - копия с помощью метода .copy(), который создаёт независимую от изначального списка копию 
copy2 = original[:] # срез - с помощью пустого среза
copy3 = list(original) # конструктор - с помощью функции-конструктора list()
copy4 = [*original] # распаковка - с помощью распаковки через *
# Все эти способы дают нам независимую копию исходного списка. Главное помнить, что другие вложенные объекты будут изменяемы (если это например списки)
print(copy1, copy2, copy3, copy4)
# Out:
# [1, 2, 3] [1, 2, 3] [1, 2, 3] [1, 2, 3]

# %% [markdown]
# ### Глубокое копирование.
# Метод `.copy()` создаёт *поверхностную копию*. Если внутри списка есть
# другие изменяемые объекты (например, вложенные списки), они не
# копируются — копируются только ссылки на них.

# %%
import copy

original = [[1, 2], [3, 4]]
shallow = original.copy() # поверхностная копия
deep = copy.deepcopy(original) # глубокая копия - нужна для того, чтобы даже вложенные объекты типо списков в двумерных списках не изменялись при изменении их в оригинальном списке

original[0][0] = 99

print("Оригинал:", original)
print("Поверхностная копия:", shallow) # изменилась!
print("Глубокая копия:", deep) # а в глубоком списке нет
# Out:
# Оригинал: [[99, 2], [3, 4]]
# Поверхностная копия: [[99, 2], [3, 4]]
# Глубокая копия: [[1, 2], [3, 4]]

# %% [markdown]
# ## Не только вызовы функций
# Проблемы, аналогичные рассмотренным выше, возникают не только при
# вызове функций. Начнём с простого примера с циклом.

# %%
some_list = [7, 9, 11]
for x in some_list:
    x = x + 1
print(some_list)
# Out:
# [7, 9, 11]

# %% [markdown]
# Список `some_list` не поменялся, и в этом нет ничего удивительного.
# Но давайте теперь рассмотрим чуть более сложную ситуацию со списком
# списков.

# %%
table = [[1, 5], [7, 9]]
for row in table:
    row.append(77)
print(table)
# Out:
# [[1, 5, 77], [7, 9, 77]]

# %% [markdown]
# И снова «ой». Что случилось? Посмотрим на визуализаторе.

# %%
# %%tutor --lang python3
# table = [[1, 5], [7, 9]]
# for row in table:
#     row.append(77)
# print(table)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="http://pythontutor.com/iframe-embed.html#code=table%20%3D%20%5B%5B1%2C%205%5D%2C%20%5B7%2C%209%5D%5D%0Afor%20row%20in%20table%3A%0A%20%20%20%20row.append%2877%29%0Aprint%28table%29%0A&origin=opt-frontend.js&cumulative=false&heapPrimitives=false&textReferences=false&curInstr=0&&verticalStack=false&py=3&rawInputLstJSON=%5B%5D&codeDivWidth=50%25&codeDivHeight=100%25"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# При выполнении первого шага цикла (Step 3) в переменную row
# записывается первый элемент списока `table` . Однако, этот элемент сам
# является списком — а точнее ссылкой на список. На следующем шаге
# (Step 4) к этому списку добавляется элемент `77` . Потом row
# становится ссылкой на второй элемент списка `table` . К ней тоже
# добавляется элемент `77`.
#
# Обратите внимание на параллель с предыдущим сюжетом: здесь тоже
# участвует вызов метода списка, который меняет этот список *in place*.

# %% [markdown]
# # Головоломка

# %% [markdown]
# Как вы думаете, что будет, если выполнить следующий код? Попробуйте
# его выполнить, посмотрите на результат и попытайтесь объяснить.

# %%
A = [[]]*5
A[0].append(1)
print(A)
# Out:
# [[1], [1], [1], [1], [1]]

# %% [markdown]
# Прикол в том, что при создании списка `A = [[]]*5` создаётся не пять разных пустых списков, а пять ссылок на один и тот же список.
#
# Умножение списка повторяет ссылки на внутренний объект, а не создаёт его копии. Поэтому когда мы делаем `A[0].append(1)`, мы добавляем единицу в тот единственный внутренний список, на который ссылаются все пять элементов `A`. В результате `print(A)` показывает один и тот же список, повторённый пять раз, но уже с единицей внутри.
#
# Чтобы получить пять независимых списков, нужно использовать генератор списка:
# ```py
# A = [[] for _ in range(5)]
# ```

# %% [markdown]
# # Изменение итерируемого объекта в цикле
# В примере выше мы меняли содержимое «внутренних» списков, но сам
# список `table` оставался неизменным: в нём не менялось число
# элементов и элементы оставались ссылками на те же самые спискистроки, что и раньше. А можно ли менять сам список во время
# итераций? Оказывается, можно. Хотя в большинстве случаев лучше
# этого не делать. Прежде, чем рассматривать пример, напомним о том, как
# работает метод `.pop()` у списка:

# %%
L = [6, 9, 44, 8]
print(L.pop()) # метод .pop() удаляет из исходного списка элемент. В качестве аргумента передаётся индекс, на удаляемый элемент (по умолчанию это -1)
print(L)
# Out:
# 8
# [6, 9, 44]

# %% [markdown]
# Он удаляет последний элемент из списка и возвращает его же. Применим
# теперь его следующим образом:

# %%
L = [7, 8, 9, 10]
for x in L:
    print("Pop element", L.pop()) # тут удаляются поочерёдно элементы. Сначала -1, потом -2 (но на второй итерации это уже будет -1)
    print(x)
# Out:
# Pop element 10
# 7
# Pop element 9
# 8

# %% [markdown]
# Цикл исполняется два раза: к тому моменту, как цикл закончит
# обрабатывать элемент 8, элементы 9 и 10 из списка будут уже удалены,
# необработанных элементов в списке не останется и цикл прекратится.
#
# Догадаться о том, что произойдёт, можно лишь очень внимательно
# изучив код. Это значит, что код не очень хорош: глядя на хороший код,
# вы можете понять, что он будет делать.
#
# Со словарями ситуация иная.

# %%
d = {1:2, 3:4}
for k, v in d.items(): # перебираем все ключи и их значения
    del d[3] # удаляем по ключу 3
    print(k, v)
# Out:
# 1 2
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 2
#       1 d = {1:2, 3:4}
# ----> 2 for k, v in d.items(): # перебираем все ключи и их значения
#       3     del d[3] # удаляем по ключу 3
#       4     print(k, v)
#
# RuntimeError: dictionary changed size during iteration

# %% [markdown]
# Здесь команда `del d[3]` удаляет элемент с ключом `3` из словаря.
# Поскольку порядок итерирования элементов словаря не определён, как
# корректно продолжить итерации после того, как размер словаря был
# изменён, никто не знает. Поэтому такая операция запрещена.
#
# Однако, это не означает, что запрещено менять значение словаря при
# выполнении цикла. Например, мы хотим прибавить ко всем значениям
# число 1. Следующий наивный метод ожидаемо не сработает:

# %%
d={1:2, 3:4}
for k, v in d.items(): # аналогично перебираем все ключи и значения
    v = v + 1          # к каждому значению добавляем 1
print(d)               # ничего не изменилось
# Out:
# {1: 2, 3: 4}

# %% [markdown]
# На самом деле, эту задачу следует решать так:

# %%
d = {1:2, 3:4}
for k in d:         # теперь перебираем только ключи
    d[k] = d[k] + 1 # по каждому ключу изменяем значение на 1
print(d)            # вот теперь работает
# Out:
# {1: 3, 3: 5}

# %% [markdown]
# # Множества
# Ещё один базовый тип данных в Python — это множество. Оно
# соответствует математическому понятию множества — то есть набора
# каких-то элементов. Каждый элемент может или входить в множество,
# или не входить.
#
# > Если вы в данный момент являетесь слушателем нашего
# > курса по Python, то вы принадлежите множеству
# > слушателей. Нельзя быть «дважды слушателем курса»:
# > каждый элемент может входить в множество только один раз.

# %%
my_set = {6, 9, 11, 11, 9, 'hello'} # создали множество myset

# %%
my_set # выводим на экран - что видим? Видим, что повторяющиеся элементы не учитываются, а также изменился порядок
# Out:
# {11, 6, 9, 'hello'}

# %% [markdown]
# Как видно из этого простого примера, элементы множества также не
# упорядочены.

# %%
{6, 9, 11, 11, 9, 'hello'} == {9, 'hello', 11, 6} # делаем вывод - элементы во множестве не упорядочены
# Out:
# True

# %% [markdown]
# Вот так можно проверить, лежит ли элемент в множестве.

# %%
9 in my_set # также можно проверять наличие элемента во множестве с помощью оператора in
# Out:
# True

# %%
10 in my_set
# Out:
# False

# %% [markdown]
# Конечно, оператор `in` работает не только для множеств. Например, `4 in [2, 4, 8, 10]` вернёт `True`. Однако для списков эта операция
# является медленной — вернее, *массовой*: чем больше список, тем
# больше операций сравнения нужно произвести, чтобы понять, лежит ли
# в нём какой-то конкретный элемент. В случае с множествами время на
# проверки практически не растёт с ростом числа элементов множества.
#
# С множествами можно делать разные операции — с ними мы знакомы по
# математическим курсам. Например, объединение и пересечение двух
# множеств даёт новое множество:

# %%
{6, 8, 9} | {6, 11, 7} # объединение множеств
# Out:
# {6, 7, 8, 9, 11}

# %%
{6, 8, 9} & {6, 11, 7} # пересечение множеств
# Out:
# {6}

# %% [markdown]
# ## Дополнительные операции над множествами

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# Разность
print("Разность A - B:", A - B)
print("Разность B - A:", B - A)

# Симметрическая разность
print("Симметрическая разность:", A ^ B)

# Проверка на подмножество
print("{1, 2} ⊆ A?", {1, 2}.issubset(A))
print("A ⊇ {1, 2}?", A.issuperset({1, 2}))
# Out:
# Разность A - B: {1, 2}
# Разность B - A: {5, 6}
# Симметрическая разность: {1, 2, 5, 6}
# {1, 2} ⊆ A? True
# A ⊇ {1, 2}? True

# %% [markdown]
# > Отметим ещё раз: порядок элементов во множестве не определён. Если вам нужно вывести элементы множества в каком-то заранее заданном порядке, то можно превратить его в сортированный список с помощью функции `sorted()`.

# %%
s = {"Hello", "World", "Test","Zzzzz","Zz","Q"}
print(s)
# здесь выводится уже не множество, а список, ведь функция sorted() всегда возвращает список
print(sorted(s))
# Out:
# {'Zzzzz', 'Zz', 'Hello', 'World', 'Test', 'Q'}
# ['Hello', 'Q', 'Test', 'World', 'Zz', 'Zzzzz']

# %% [markdown]
# ## Пример использования множеств

# %% [markdown]
# Предположим, мы просим пользователя ввести команду, но хотим дать
# ему возможность ввести одну и ту же команду разными способами.
# Например, чтобы остановить программу, пользователь может ввести
# слово `stop` или `STOP` или `Stop` или просто букву `s` . Можно
# обработать этот случай с помощью нескольких условий, соединённых
# `or` :

# %%
s = 'stop'
if s == 'stop' or s == 'Stop' or s == 'STOP' or s == 's': # можно проверить с помощью огромного условия
    print("Хорошо, останавливаемся")
# Out:
# Хорошо, останавливаемся

# %% [markdown]
# А можно создать множество для всех возможных вариаций команды
# `stop` и проверять, входит ли наша команда в это множество:

# %%
s = 'stop'
STOPS = {'stop', 'Stop', 'STOP', 's'}
if s in STOPS: # а можно проверять вхождение с помощью множества и оператора in
    print("Хорошо, останавливаемся")
# Out:
# Хорошо, останавливаемся

# %% [markdown]
# Впрочем, в этом месте, вероятно, вместо множества можно было бы
# использовать и просто список.

# %% [markdown]
# # Ещё немного про строки
# Я давно собирался рассказать про методы для работы со строками.
# Вообще этих методов существует много и про все не расскажу, но
# некоторые из них мы сейчас обсудим.

# %%
s = "hello world, hello"
new_s = s.replace("hello", "Hi") # метод .replace() позволяет нам заменить подстроку на другую подстроку заднное кол-во раз (третим параметром передаётся кол-во замен, но по умолчанию - до бесконечности (-1))
print(new_s)
print(s)
# Out:
# Hi world, Hi
# hello world, hello

# %% [markdown]
# Вот так, например, можно заменить подстроку в строке. Обратите
# внимание: строка является неизменяемым типом данных, поэтому, в
# отличие от методов списков типа `append()` методы строк никогда не
# меняют саму строку (это вообще невозможно), а вместо этого создают
# новую строку и возвращают результат.
#
# Если вы хотели заменить только несколько первых вхождений
# (например, только первое слово `hello` , но не второе), можно было
# добавить третий аргумент метода `replace` — он показывает, сколько
# раз нужно произвести замену.

# %%
"hello world, hello".replace("hello", "Hi", 1) # вот здесь мы видим, что произошла только 1 замена
# Out:
# 'Hi world, hello'

# %% [markdown]
# Вот так можно найти подстроку в строке:

# %%
s.index("world") # с помощью метода .index() можно получить первый индекс (индекс первого символа подстроки в строке) вхождения подстроки в строку
# Out:
# 6

# %%
s.find("world") # аналогично .index(), но в методе .find() используется проверка. Если в .index() подстрока не будет найдена, то выдастся ошибка, а в .find() вернётся -1
# Out:
# 6

# %% [markdown]
# Оба метода возвращают индекс первого символа подстроки. Разница
# состоит в том, что если `index()` не сможет найти подстроку вообще,
# он выдаст ошибку (exception), а если с аналогичной проблемой
# столкнётся `find()`, то он вернёт число -1 в качестве индекса.
#
# Кстати, проверить, входит ли подстрока в строку, можно ещё вот так:

# %%
"world" in s # можно также проверять вхождение подстроки в строку с помощью оператора in, и он будет возвращать значение типа bool
# Out:
# True

# %% [markdown]
# А вот так можно посчитать, сколько подстрок в строке встречается:

# %%
s.count("o") # метод .count() подсчитывает количество вхождений подстроки в строку
# Out:
# 3

# %% [markdown]
# ## Полезные строковые методы

# %%
text = " Hello, World! "

# strip() — удаление пробелов в начале и конце
print(text.strip()) # "Hello, World!"
print(text.lstrip()) # "Hello, World! "
print(text.rstrip()) # " Hello, World!"

# Проверки содержимого
print("12345".isdigit()) # True - проверяет, являются ли все символы - цифрами
print("abc".isalpha()) # True - проверяет, являются ли все символы - буквами
print("abc123".isalnum()) # True - проверяет, являются ли все символы - цифрами (в том числе и буквы, например A=10)
print("Hello".startswith("He")) # True - проверяет, начинается ли строка на подстроку
print("Hello".endswith("lo")) # True - проверяет, заканчивается ли строка на подстроку
# Out:
# Hello, World!
# Hello, World!
#  Hello, World!
# True
# True
# True
# True
# True

# %% [markdown]
# Подробности можно найти в [официциальной справке](https://docs.python.org/3/library/string.html).

# %% [markdown]
# # Файловый ввод-вывод
# Мы начинаем работать с файлами. Сейчас будем обсуждать только
# чтение и запись. О том, как запускать файлы на исполнение, отдельная
# история — для этого существует метод `subprocess` , мы до него когда-нибудь дойдём. (Может быть.) Также для начала речь пойдёт о текстовых
# файлах или похожих на текстовые (например, код на Python или CSVфайл будет текстовым). Бывают также бинарные файлы, которые читать
# бесполезно, про них также будет информация дальше.
#
# Допустим, мы хотим прочитать файл.
#
# Примечание: Нужно создать текстовый файл `func.txt` в каталоге, в
# котором находится файл текущего интерактивного блокнота. В этот файл
# нужно внести строки:
#
# ```txt
# blockdiag {
#     args [label="Аргументы"]
#     function [label="Функция"]
#     sideffects [label="Сторонние эффекты"]
#     output [label="Возвращаемое значение"]
#
#     args -> function -> output;
#     function -> sideffects;
# }
# ```

# %%
f = open("func.txt", encoding="UTF-8") # открытие файла происходит с помощью функции open(), куда мы передаём директорию файла, "метод" открытия (ну и ещё я добавил кодировку, чтобы не вылезала кракозябра вместо кириллических букв)
s = f.read() # для файлов определена целая туча методов: один из них - .read() Он возвращает строку из содержимого всего файла (или заданного промежутка данных из него)
f.close() # также после работы с файлом его необходимо закрыть с помощью метода .close()
print(s)
# Out:
# blockdiag {
#     args [label="Аргументы"]
#     function [label="Функция"]
#     sideffects [label="Сторонние эффекты"]
#     output [label="Возвращаемое значение"]
#
#     args -> function -> output;
#     function -> sideffects;
# }

# %% [markdown]
# Что здесь произошло? Во-первых, мы открыли для чтения файл
# `func.txt`, лежащий в нашем текущем рабочем каталоге. Узнать, какой
# каталог рабочий, можно следующим образом:

# %%
import os
os.getcwd() # функция getcwd() возвращает нам текущую директорию, т.е. если необходимый нам файл лежит в корне папки, где и сам скрипт, то нам не надо прописывать к нему путь
# Out:
# 'd:\\Dev\\SevSU\\1_Course\\2_Term\\Python_Programming\\lab_07'

# %% [markdown]
# Функция `open()` вернула объект типа `file` — переменную, которую
# можно использовать, чтобы работать с файлом. Затем мы считали
# содержимое файла в строчку `s`, после чего закрыли файл. Закрывать
# файлы очень полезно: если вы забудете закрыть файл, другое
# приложение не сможет его открыть (например, чтобы в него что-нибудь
# записать).

# %% [markdown]
# ## Контекстный менеджер `with`
# Более безопасный и рекомендуемый способ работы с файлами —
# использовать конструкцию `with`. Она автоматически закрывает файл,
# даже если произошла ошибка.

# %%
with open("func.txt", encoding="UTF-8") as f: # чтобы не забывать закрывать за собой (дверь) файл, можно использовать контекстный менеджер with
    content = f.read()
    print(content)
# файл автоматически закрыт здесь
# Out:
# blockdiag {
#     args [label="Аргументы"]
#     function [label="Функция"]
#     sideffects [label="Сторонние эффекты"]
#     output [label="Возвращаемое значение"]
#
#     args -> function -> output;
#     function -> sideffects;
# }

# %% [markdown]
# Функция `read()` считает весь файл в одну большую строковую
# переменную. Это не всегда бывает удобно (учитывая, что строки в
# Python неизменяемые и из-за этого работа с ними не всегда бывает
# эффективной), поэтому есть разные другие сценарии работы с файлами.
# Например, можно считать содержимое файла в список, разбив по
# строкам.

# %%
f = open("func.txt", encoding="UTF-8")
lines = f.readlines() # метод .readlines() возвращает нам список из всех строк файла (а read() возвращает весь файл в одной строке)
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
print(lines)
# Out:
# ['blockdiag {\n', '    args [label="Аргументы"]\n', '    function [label="Функция"]\n', '    sideffects [label="Сторонние эффекты"]\n', '    output [label="Возвращаемое значение"]\n', '\n', '    args -> function -> output;\n', '    function -> sideffects;\n', '}']

# %% [markdown]
# Заметим, что каждая из строк заканивается символом перевода строки
# `\n` — они присутствовали в файле и мы их честно из него считали. Вот
# так можно вывести файл по строкам, пронумеровав их:

# %%
for i, line in enumerate(lines, 1):
    print(i, line, end="")
# Out:
# 1 blockdiag {
# 2     args [label="Аргументы"]
# 3     function [label="Функция"]
# 4     sideffects [label="Сторонние эффекты"]
# 5     output [label="Возвращаемое значение"]
# 6
# 7     args -> function -> output;
# 8     function -> sideffects;
# 9 }

# %% [markdown]
# Другой способ это сделать — не создавать отдельный список, а
# итерировать прямо сразу файловый объект.

# %%
f = open("func.txt", encoding="UTF-8")
for i, line in enumerate(f, 1):
    print(i, line, end="")
f.close()
# Out:
# 1 blockdiag {
# 2     args [label="Аргументы"]
# 3     function [label="Функция"]
# 4     sideffects [label="Сторонние эффекты"]
# 5     output [label="Возвращаемое значение"]
# 6
# 7     args -> function -> output;
# 8     function -> sideffects;
# 9 }

# %% [markdown]
# Этот метод является более предпочтительным, если файл большой. В
# этом случае считать его в память целиком может быть невозможно, а
# обработать по одной строчке — вполне возможно.
#
# Здесь есть, правда, некоторые хитрости. Рассмотрим, например, такой
# код:

# %%
f = open("func.txt", encoding="UTF-8")
for line in f:
    print(line, end="")
print("----Следующий----")
for line in f:
    print(line, end="")
f.close()
# Out:
# blockdiag {
#     args [label="Аргументы"]
#     function [label="Функция"]
#     sideffects [label="Сторонние эффекты"]
#     output [label="Возвращаемое значение"]
#
#     args -> function -> output;
#     function -> sideffects;
# }----Следующий----

# %% [markdown]
# Что здесь произошло? Почему второй цикл вообще не выполнился
# (ничего не выведено после строчки `----Следующий----` )? Очень
# просто: переменная `f` , хоть и прикидывается списком строк, когда мы
# её итерируем, на самом деле таковым не является. В действительности
# при открытии файла мы запоминаем позицию, на которой мы этот файл
# читаем. Изначально она указывает на самое начало файла, но с каждой
# итерацией сдвигается. Когда мы прочитаем файл целиком, дальнейшие
# попытки из него что-то прочитать ни к чему не приведут: указатель
# текущей позиции сдвинулся до самого конца и файл закончился.
#
# Впрочем, есть возможность вернуться в начало: для этого нужно
# использовать метод `seek()` .

# %%
f = open("func.txt", encoding="UTF-8")
for line in f:
    print(line, end="")
print("\n\n----Следующий----\n\n")
f.seek(0) # возврат каретки в начало файла (ну на заданный индекс)
for line in f:
    print(line, end="")
f.close()
# Out:
# blockdiag {
#     args [label="Аргументы"]
#     function [label="Функция"]
#     sideffects [label="Сторонние эффекты"]
#     output [label="Возвращаемое значение"]
#
#     args -> function -> output;
#     function -> sideffects;
# }
#
# ----Следующий----
#
#
# blockdiag {
#     args [label="Аргументы"]
#     function [label="Функция"]
#     sideffects [label="Сторонние эффекты"]
#     output [label="Возвращаемое значение"]
#
#     args -> function -> output;
#     function -> sideffects;
# }

# %% [markdown]
# ## Запись в файлы
# Чтобы содать файл и записать в него что-то, нужно открыть его *на
# запись*. Это делается путём передачи функции open второго аргумента
# — здесь надо написать строчку `"w"` (от *write*).
#
# > **Внимание!** Если файл, который вы пытаетесь открыть на запись, уже существует, он будет **удалён без какого-либо предупреждения.**
#
# 3аписывать информацию в файл, открытый на запись, можно, например,
# с помощью метода `write()`.

# %%
f = open("other.txt", "w") # вот мы и добрадись до записи в файлы. Чтобы записать что-то в файл его необходимо открыть в режиме записи ("w")
f.write("Hello\n") # метод .write() позволяет нам записать что-то в файл (возвращает кстати кол-во успешно записанных символов)
f.close()

# %% [markdown]
# Проверим, что получилось:

# %%
open("other.txt").read()
# Out:
# C:\Users\zavar\AppData\Local\Temp\ipykernel_10536\59306033.py:1: ResourceWarning: unclosed file <_io.TextIOWrapper name='other.txt' mode='r' encoding='cp1251'>
#   open("other.txt").read()
# ...
# 'Hello\n'

# %% [markdown]
# Мы видим, что действительно записали в файл `other.txt` строчку
# `Hello\n`. Заметим, что здесь мы открыли файл на запись, но не стали
# присваивать файловый объект какой-либо переменной, а сразу вызвали
# от него метод `read()`. В этом случае файл будет закрыт автоматически
# через некоторое время после выполнения этой команды. (Система
# выдаёт предупреждение о том, что мы не закрыли файл явно — в
# некоторых случаях это может приводить к каким-то проблемам.)

# %% [markdown]
# ### Режимы открытия файлов
# Функция `open()` принимает второй аргумент — режим:
# + `'r'` — чтение (по умолчанию)
# + `'w'` — запись (стирает существующий файл)
# + `'a'` — дозапись в конец файла (append)
# + `'r+'` — чтение и запись
# + `'b'` — бинарный режим (добавляется к другим, например `'rb'`
# или `'wb'`)

# %%
# Дозапись в файл
with open("other.txt", "a", encoding="UTF-8") as f:
    f.write("Дополнительная строка\n")

# Запись нескольких строк через writelines
with open("lines.txt", "w", encoding="UTF-8") as f:
    f.writelines(["Первая строка\n", "Вторая строка\n"]) # записывать несколько строк можно с помощью .writelines()

# %% [markdown]
# ## Бинарные файлы
# Бинарные файлы хранят данные в том виде, в котором они представлены
# в памяти компьютера, а не в виде текста. Их нельзя открыть в обычном
# текстовом редакторе — вы увидите «иероглифы». Бинарный режим
# полезен при работе с изображениями, аудио, видео, архивами, а также
# при сохранении сложных структур данных (например, через `pickle` -
# будет рассматриваться дальше).
#
# В бинарном режиме методы `read()` и `write()` работают с объектами
# типа `bytes`, а не со строками ( `str` ).
#
# ```py
# # Пример: копирование бинарного файла
# with open("image.jpg", "rb") as src:
#     with open("copy.jpg", "wb") as dst:
#         dst.write(src.read())
# ```
#
# При чтении бинарных данных помните: `f.read()` вернёт `bytes`, а не
# `str`. Для преобразования между `bytes` и `str` используйте методы
# `.encode()` и `.decode()` или конструкторы `bytes()` и `str()`.

# %%
# Запись бинарных данных
data = bytes([65, 66, 67, 68]) # задаём объект bytes() для работы с бинарными файлами, ведь они не любят строки и прочие классы (будет ABCD)
with open("binary.bin", "wb") as f:
    f.write(data)

# Чтение бинарных данных
with open("binary.bin", "rb") as f:
    read_data = f.read()
    print(read_data) # b'ABCD' - выдало так, ведь нам расшифровало 65 66 67 68
    print(list(read_data)) # [65, 66, 67, 68]
# Out:
# b'ABCD'
# [65, 66, 67, 68]

# %% [markdown]
# Есть и другие методы для работы с файлами, но на сегодня это всё.
#
# <hr color="#b700ff">

# %% [markdown]
# # Практические задачи

# %% [markdown]
# 1.  Напишите функцию, которая принимает список и число, добавляет
# это число в список (изменяя исходный список) и возвращает его.

# %%
from random import randint

my_list = [randint(-10, 10) for _ in range(15)]

def sorted_list(src_list, num):
    src_list.append(num)
    return src_list

print("До:", my_list)
print("Функция:", sorted_list(my_list, 95))
print("После:", my_list)
# Out:
# До: [-1, -9, -2, -8, 9, 10, -5, 9, -2, -6, -6, 8, -5, 4, -5]
# Функция: [-1, -9, -2, -8, 9, 10, -5, 9, -2, -6, -6, 8, -5, 4, -5, 95]
# После: [-1, -9, -2, -8, 9, 10, -5, 9, -2, -6, -6, 8, -5, 4, -5, 95]

# %% [markdown]
# 2. Напишите функцию, которая принимает список и число, а
# возвращает **новый** список, который является копией исходного с
# добавленным в конец числом, не изменяя исходный список.

# %%
my_list = [randint(-10, 10) for _ in range(15)]

def sorted_list(src_list, num):
    new_list = src_list.copy()
    new_list.append(num)
    return new_list

print("До:", my_list)
print("Функция:", sorted_list(my_list, 95))
print("После:", my_list)
# Out:
# До: [-4, -1, -1, 7, -4, -10, -1, -10, 6, -7, 8, 4, 3, -1, -3]
# Функция: [-4, -1, -1, 7, -4, -10, -1, -10, 6, -7, 8, 4, 3, -1, -3, 95]
# После: [-4, -1, -1, 7, -4, -10, -1, -10, 6, -7, 8, 4, 3, -1, -3]

# %% [markdown]
# 3. Создайте список из 5 одинаковых вложенных списков (например,
# `[[0]] * 5` ), затем измените первый элемент первого вложенного
# списка на 1. Объясните, почему изменились все вложенные списки.

# %%
arr = [[0]]*5
arr[0][0] = 1
print(arr)
# Out:
# [[1], [1], [1], [1], [1]]

# %% [markdown]
# 4. Даны два списка. Напишите код, который создаёт множество из
# элементов, которые встречаются хотя бы в одном из списков
# (объединение).

# %%
a = [randint(-5, 5) for _ in range(10)]
b = [randint(-5, 5) for _ in range(10)]
print(a, b)

a = set(a)
b = set(b)

print(a | b)
# Out:
# [3, -3, -2, 5, -3, 5, 3, 2, 0, 2] [1, 5, 5, -1, 3, 5, -2, 3, -3, 3]
# {0, 1, 2, 3, 5, -1, -3, -2}

# %% [markdown]
# 5. Напишите код, который проверяет, все ли символы в строке
# являются цифрами, и выводит соответствующее сообщение.

# %%
my_str = "1725"
print(my_str.isdecimal()) # также можно использовать .isdigit если необходимо проверять на цифры и некоторые спец.символы, а также .isnumeric - если необходимо проверять на числа (даже римские)
# Out:
# True

# %% [markdown]
# 6. Напишите программу, которая заменяет в строке все вхождения
# слова `"плохо"` на `"хорошо"` и выводит результат, не изменяя
# исходную строку.

# %%
my_str = "Всё плохо"
print(my_str.replace("плохо", "хорошо"))
print(my_str)
# Out:
# Всё хорошо
# Всё плохо

# %% [markdown]
# 7.  Создайте текстовый файл `test.txt` и запишите в него три строки:
# `"Первая"` , `"Вторая"` , `"Третья"` . Затем прочитайте файл и
# выведите каждую строку с её номером.

# %%
file = open("test.txt", "w")
file.write("Первая\n")
file.write("Вторая\n")
file.write("Третья")
file.close()

f = open("test.txt")
for i, line in enumerate(f, 1):
    print(i, line, end="")
# Out:
# 1 Первая
# 2 Вторая
# 3 Третья

# %% [markdown]
# 8. Напишите код, который читает файл `data.txt` построчно с
# помощью цикла `for` , не загружая весь файл в память целиком.
#
# Содержание файла data.txt:
# ```txt
# Hello World!
# My name is Arsenii
# I'm 18 y.o.
# I'm a student of Sevastopol State University
# I'm from Severodvinsk, Arkhangelskaya obl.
# ```

# %%
file = open("data.txt")
for line in file:
    print(line, end="")
# Out:
# Hello World!
# My name is Arsenii
# I'm 18 y.o.
# I'm a student of Sevastopol State University
# I'm from Severodvinsk, Arkhangelskaya obl.

# %% [markdown]
# 9. Дана строка `s = " hello world "`. Удалите пробелы в начале
# и конце строки, затем проверьте, начинается ли строка с `"hello"`.

# %%
s = " hello world "
s = s.strip()
print(s)
if s.find("hello") == 0:
    print("Стркоа начинается с hello")
else:
    print("Строка НЕ начинается с hello")
# Out:
# hello world
# Стркоа начинается с hello

# %% [markdown]
# 10. Создайте множество из букв слова `"программирование"` и
# выведите количество уникальных букв в этом слове.

# %%
my_set = set()

for i in "программирование":
    my_set.add(i)

print(my_set)
print(len(my_set))
# Out:
# {'е', 'а', 'р', 'г', 'м', 'п', 'н', 'о', 'и', 'в'}
# 10

# %% [markdown]
# <hr color="#b700ff">
